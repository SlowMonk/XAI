# %%
#!pip uninstall tensorflow-gpu

# %%
#!pip install tensorflow-gpu
#!y
#!pip show tensorflow
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from PIL import Image as pil_image
import cv2

import glob

import tensorflow as tf
from tensorflow.python.keras.models import model_from_json
from tensorflow.python.keras import backend as K
from tensorflow.python.framework import ops


import scipy
from scipy import ndimage
from skimage.measure import label, regionprops

from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D , GlobalAveragePooling2D,ZeroPadding2D


import tensorflow as tf
import warnings
import seaborn as sns
import matplotlib.pylab as plt
import PIL
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50

from tensorflow.keras import layers, models, optimizers

import tensorflow as tf
import numpy as np

from tensorflow.keras import layers, models, optimizers
import warnings
import seaborn as sns
import matplotlib.pylab as plt
import PIL
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications import VGG16,VGG19,ResNet50,DenseNet201,MobileNetV2,DenseNet121
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras import layers, models, optimizers



warnings.filterwarnings('ignore')

application = Xception
batch_size = 32

# %matplotlib inline

# %%
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
from __future__ import print_function
import tensorflow.keras as keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import os

batch_size = 32
num_classes = 10
epochs = 20
data_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')



os.environ["CUDA_VISIBLE_DEVICES"]="1";  
from keras.backend.tensorflow_backend import set_session
config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.8
tf.compat.v1.Session(config=config)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
def get_model():
    base_model = ResNet50(weights='imagenet', input_shape=(32,32,3), include_top=False)
    #base_model.trainable = False

    model = models.Sequential()
    model.add(base_model)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(10, activation='softmax'))
    model.summary()

    #optimizer = optimizers.SGD(lr=1e-4, decay=1e-6, momentum=0.9, nesterov=True)
    optimizer = optimizers.RMSprop(lr=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

    return model

# %%
model = get_model()
#model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 1, 1, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 25,696,138
# Trainable params: 25,643,018
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
# initiate RMSprop optimizer
#opt = tensorflow.keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)
optimizer = optimizers.RMSprop(lr=0.0001)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
#model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['acc'])


x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              use_multiprocessing=True,
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        use_multiprocessing=True,
                        workers=4)

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# Epoch 1/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.4545 - accuracy: 0.5411WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 420s 269ms/step - loss: 1.4539 - accuracy: 0.5412 - val_loss: 1.8428 - val_accuracy: 0.6361
# Epoch 2/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.9649 - accuracy: 0.7016WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 420s 269ms/step - loss: 0.9648 - accuracy: 0.7016 - val_loss: 0.8897 - val_accuracy: 0.7500
# Epoch 3/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.9219 - accuracy: 0.7306WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 412s 264ms/step - loss: 0.9220 - accuracy: 0.7306 - val_loss: 1.0583 - val_accuracy: 0.7571
# Epoch 4/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.8525 - accuracy: 0.7506WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 410s 263ms/step - loss: 0.8523 - accuracy: 0.7506 - val_loss: 0.8025 - val_accuracy: 0.7758
# Epoch 5/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7891 - accuracy: 0.7641WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 412s 264ms/step - loss: 0.7890 - accuracy: 0.7641 - val_loss: 1.0189 - val_accuracy: 0.7754
# Epoch 6/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7779 - accuracy: 0.7721WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 404s 259ms/step - loss: 0.7778 - accuracy: 0.7721 - val_loss: 1.3206 - val_accuracy: 0.7510
# Epoch 7/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7595 - accuracy: 0.7840WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 398s 255ms/step - loss: 0.7598 - accuracy: 0.7840 - val_loss: 0.8503 - val_accuracy: 0.7872
# Epoch 8/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7294 - accuracy: 0.7902WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 399s 255ms/step - loss: 0.7294 - accuracy: 0.7902 - val_loss: 0.7982 - val_accuracy: 0.8002
# Epoch 9/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7223 - accuracy: 0.7965WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 400s 256ms/step - loss: 0.7223 - accuracy: 0.7965 - val_loss: 1.2981 - val_accuracy: 0.7657
# Epoch 10/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6917 - accuracy: 0.7985WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 409s 261ms/step - loss: 0.6916 - accuracy: 0.7985 - val_loss: 1.1002 - val_accuracy: 0.7821
# Epoch 11/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6855 - accuracy: 0.8044WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 403s 258ms/step - loss: 0.6854 - accuracy: 0.8044 - val_loss: 0.7289 - val_accuracy: 0.8056
# Epoch 12/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6766 - accuracy: 0.8083WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 400s 256ms/step - loss: 0.6764 - accuracy: 0.8084 - val_loss: 1.3456 - val_accuracy: 0.7702
# Epoch 13/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6463 - accuracy: 0.8191WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 396s 253ms/step - loss: 0.6462 - accuracy: 0.8191 - val_loss: 0.7085 - val_accuracy: 0.8195
# Epoch 14/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6378 - accuracy: 0.8195WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 393s 252ms/step - loss: 0.6377 - accuracy: 0.8195 - val_loss: 1.2146 - val_accuracy: 0.7737
# Epoch 15/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6174 - accuracy: 0.8248WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 392s 251ms/step - loss: 0.6174 - accuracy: 0.8247 - val_loss: 1.0271 - val_accuracy: 0.7969
# Epoch 16/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5980 - accuracy: 0.8307WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 392s 251ms/step - loss: 0.5979 - accuracy: 0.8307 - val_loss: 1.4845 - val_accuracy: 0.7773
# Epoch 17/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6060 - accuracy: 0.8318WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 407s 260ms/step - loss: 0.6059 - accuracy: 0.8318 - val_loss: 2.0416 - val_accuracy: 0.7339
# Epoch 18/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6053 - accuracy: 0.8301WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 410s 263ms/step - loss: 0.6057 - accuracy: 0.8301 - val_loss: 0.8649 - val_accuracy: 0.8116
# Epoch 19/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5899 - accuracy: 0.8379WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 398s 255ms/step - loss: 0.5896 - accuracy: 0.8380 - val_loss: 0.8936 - val_accuracy: 0.7957
# Epoch 20/20
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5659 - accuracy: 0.8412WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# 1563/1563 [==============================] - 393s 251ms/step - loss: 0.5658 - accuracy: 0.8412 - val_loss: 1.0994 - val_accuracy: 0.8033
# Saved trained model at /home/jake/Gits/AI college/saved_models/keras_cifar10_trained_model.h5
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test loss: 24.64931548681259
# Test accuracy: 0.8003

# %%
first_image = x_test[3]
print(first_image.shape)
# Out:
# (32, 32, 3)

# %% [markdown]
# # grad-cam

# %%
print(model.layers[0].input,model.layers[-3].output,model.layers[-1].output)
print(model.summary())
# Out:
# Tensor("input_2:0", shape=(None, 32, 32, 3), dtype=float32) Tensor("dense_2/Identity:0", shape=(None, 1024), dtype=float32) Tensor("dense_3/Identity:0", shape=(None, 10), dtype=float32)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 1, 1, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 25,696,138
# Trainable params: 25,643,018
# Non-trainable params: 53,120
# _________________________________________________________________
# None

# %%
def preprocess_input(img):
    #img = pil_image.open(img_path).resize((224, 224))
    img_arr = np.asarray(img)[:, :, :3] / 255.
    img_tensor = np.expand_dims(img_arr, 0)
    
    #print('img_arr->',img_arr.shape,'img_tensor->',img_tensor.shape)
    return img_arr, img_tensor

# %%
def generate_grad_cam(model, img_path, class_idx):
    #print("0")
    ## img_path -> preprocessed image tensor
    img_arr, img_tensor = preprocess_input(img_path)
    #print("1")
    ## get the derivative of y^c w.r.t A^k
    y_c = model.layers[-1].output.op.inputs[0][0, class_idx]
    #y_c = model.output[0, class_idx]
    #print('bd')
    #layer_output = model.get_layer('block5_conv3').output
    layer_output = model.layers[-4].output
    #print('3')
    grads = K.gradients(y_c, layer_output)[0]
    gradient_fn = K.function([model.input], [layer_output, grads, model.layers[-1].output])
    conv_output, grad_val, predictions = gradient_fn([img_tensor])
    conv_output, grad_val = conv_output[0], grad_val[0]
    
    #print("a->",grad_val,grad_val.shape)
    
    #weights = np.mean(grad_val, axis=(0, 1))
    weights = np.mean(grad_val,axis=(0,1))
    #print("b")
    cam = np.dot(conv_output, weights)
    #print("c")
    
    cam = cv2.resize(cam, (32, 32))
    
    ## Relu
    cam = np.maximum(cam, 0)
    
    cam = cam / cam.max()
    
    
    heatmap = cv2.applyColorMap(np.uint8(255*cam), cv2.COLORMAP_JET)
    heatmap[np.where(cam < 0.1)] = 0
    img_heatmap = heatmap*0.5 + img_path
    
    return img_path, cam, predictions, img_heatmap, heatmap

# %%
from scipy import ndimage

def generate_bbox(img, cam, threshold):
    labeled, nr_objects = ndimage.label(cam > threshold)
    props = regionprops(labeled)
    return props

# %%
plt.imshow(x_test[0])

# %%
img, cam, predictions,img_heatmap = generate_grad_cam(model, x_test[5], 0)
plt.imshow(img_heatmap,'gray')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-94-972068a24062> in <module>
# ----> 1 img, cam, predictions,img_heatmap = generate_grad_cam(model, x_test[5], 0)
#       2 plt.imshow(img_heatmap,'gray')
#
# <ipython-input-90-064ee4fc7e63> in generate_grad_cam(model, img_path, class_idx)
#      19
#      20     #weights = np.mean(grad_val, axis=(0, 1))
# ---> 21     weights = np.mean(grad_val,axis=(0,1))
#      22     #print("b")
#      23     cam = np.dot(conv_output, weights)
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/venv/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3255
#    3256     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3257                           out=out, **kwargs)
#    3258
#    3259
#
# ~/venv/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     136
#     137     is_float16_result = False
# --> 138     rcount = _count_reduce_items(arr, axis)
#     139     # Make this warning show up first
#     140     if rcount == 0:
#
# ~/venv/lib/python3.7/site-packages/numpy/core/_methods.py in _count_reduce_items(arr, axis)
#      55     items = 1
#      56     for ax in axis:
# ---> 57         items *= arr.shape[ax]
#      58     return items
#      59
#
# IndexError: tuple index out of range

# %%
import random

predicted_result = model.predict(x_test)
predicted_labels = np.argmax(predicted_result, axis=1)

test_labels = np.argmax(y_test, axis=1)

wrong_result = []

for n in range(0, len(test_labels)):
    if predicted_labels[n] != test_labels[n]:
        wrong_result.append(n)

samples = random.choices(population=wrong_result, k=16)

count = 0
nrows = ncols = 4

plt.figure(figsize=(12,8))

for n in samples:
    #print(n)
    count += 1
    plt.subplot(nrows, ncols, count)
    
    img, cam, predictions,img_heatmap,heatmap = generate_grad_cam(model, x_test[n], i)
    
    plt.imshow(heatmap, cmap='Greys', interpolation='nearest')
    tmp = "Label:" + str(test_labels[n]) + ", Prediction:" + str(predicted_labels[n])
    plt.title(tmp)

plt.tight_layout()
plt.show()
