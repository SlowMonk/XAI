# %%
from __future__ import absolute_import, division, print_function, unicode_literals, unicode_literals

import os

try:
  # Colab only
  # %tensorflow_version 2.x
except Exception:
    pass
import tensorflow as tf
from tensorflow import keras

tf.__version__
# Out:
# '2.0.0'

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras.models import Model
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_labels = train_labels[:1000]
test_labels = test_labels[:1000]

train_images = train_images[:1000].reshape(-1, 28 * 28) / 255.0
test_images = test_images[:1000].reshape(-1, 28 * 28) / 255.0

# %%
def model():
    
    inputs = Input(shape=(28,28,1))
    x = Conv2D(24,kernel_size=(3,3),padding='same',activation="relu")(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(48, (3, 3), padding='same',activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(64, (3, 3), padding='same',activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Flatten()(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.25)(x)
    output = Dense(num_classes,activation="softmax")(x)
    
    model = Model(inputs,output)
    
    model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
    
    return model

# %%
# 간단한 Sequential 모델을 반환합니다
def create_model():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

    return model

# %%
# 모델 객체를 만듭니다
model = model()
model.summary()

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=100,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 1.1598 - accuracy: 0.6803 - val_loss: 1.0080 - val_accuracy: 0.8120
# Epoch 2/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 1.1118 - accuracy: 0.6917 - val_loss: 0.9567 - val_accuracy: 0.8191
# Epoch 3/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 1.0703 - accuracy: 0.7011 - val_loss: 0.9095 - val_accuracy: 0.8253
# Epoch 4/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 1.0256 - accuracy: 0.7124 - val_loss: 0.8649 - val_accuracy: 0.8319
# Epoch 5/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.9837 - accuracy: 0.7221 - val_loss: 0.8248 - val_accuracy: 0.8349
# Epoch 6/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.9475 - accuracy: 0.7323 - val_loss: 0.7870 - val_accuracy: 0.8417
# Epoch 7/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.9153 - accuracy: 0.7404 - val_loss: 0.7526 - val_accuracy: 0.8463
# Epoch 8/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.8835 - accuracy: 0.7488 - val_loss: 0.7209 - val_accuracy: 0.8509
# Epoch 9/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.8521 - accuracy: 0.7580 - val_loss: 0.6910 - val_accuracy: 0.8547
# Epoch 10/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.8235 - accuracy: 0.7628 - val_loss: 0.6637 - val_accuracy: 0.8596
# Epoch 11/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.7994 - accuracy: 0.7694 - val_loss: 0.6389 - val_accuracy: 0.8629
# Epoch 12/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.7732 - accuracy: 0.7760 - val_loss: 0.6151 - val_accuracy: 0.8673
# Epoch 13/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.7477 - accuracy: 0.7828 - val_loss: 0.5932 - val_accuracy: 0.8702
# Epoch 14/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.7301 - accuracy: 0.7882 - val_loss: 0.5731 - val_accuracy: 0.8727
# Epoch 15/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.7066 - accuracy: 0.7957 - val_loss: 0.5538 - val_accuracy: 0.8745
# Epoch 16/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.6887 - accuracy: 0.7982 - val_loss: 0.5365 - val_accuracy: 0.8773
# Epoch 17/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.6712 - accuracy: 0.8030 - val_loss: 0.5200 - val_accuracy: 0.8809
# Epoch 18/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.6512 - accuracy: 0.8096 - val_loss: 0.5041 - val_accuracy: 0.8829
# Epoch 19/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.6362 - accuracy: 0.8141 - val_loss: 0.4898 - val_accuracy: 0.8855
# Epoch 20/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.6202 - accuracy: 0.8166 - val_loss: 0.4763 - val_accuracy: 0.8872
# Epoch 21/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.6092 - accuracy: 0.8205 - val_loss: 0.4639 - val_accuracy: 0.8889
# Epoch 22/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.5926 - accuracy: 0.8258 - val_loss: 0.4517 - val_accuracy: 0.8917
# Epoch 23/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.5811 - accuracy: 0.8294 - val_loss: 0.4406 - val_accuracy: 0.8942
# Epoch 24/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.5670 - accuracy: 0.8318 - val_loss: 0.4297 - val_accuracy: 0.8948
# Epoch 25/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.5577 - accuracy: 0.8344 - val_loss: 0.4200 - val_accuracy: 0.8969
# Epoch 26/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.5443 - accuracy: 0.8395 - val_loss: 0.4107 - val_accuracy: 0.8982
# Epoch 27/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.5346 - accuracy: 0.8405 - val_loss: 0.4015 - val_accuracy: 0.9000
# Epoch 28/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.5253 - accuracy: 0.8427 - val_loss: 0.3932 - val_accuracy: 0.9019
# Epoch 29/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.5161 - accuracy: 0.8468 - val_loss: 0.3855 - val_accuracy: 0.9023
# Epoch 30/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.5091 - accuracy: 0.8480 - val_loss: 0.3777 - val_accuracy: 0.9038
# Epoch 31/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4993 - accuracy: 0.8522 - val_loss: 0.3706 - val_accuracy: 0.9051
# Epoch 32/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4892 - accuracy: 0.8543 - val_loss: 0.3634 - val_accuracy: 0.9058
# Epoch 33/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4830 - accuracy: 0.8546 - val_loss: 0.3570 - val_accuracy: 0.9068
# Epoch 34/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4721 - accuracy: 0.8590 - val_loss: 0.3504 - val_accuracy: 0.9079
# Epoch 35/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4677 - accuracy: 0.8592 - val_loss: 0.3447 - val_accuracy: 0.9093
# Epoch 36/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4606 - accuracy: 0.8612 - val_loss: 0.3388 - val_accuracy: 0.9110
# Epoch 37/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4522 - accuracy: 0.8641 - val_loss: 0.3336 - val_accuracy: 0.9115
# Epoch 38/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4469 - accuracy: 0.8653 - val_loss: 0.3282 - val_accuracy: 0.9120
# Epoch 39/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4395 - accuracy: 0.8680 - val_loss: 0.3230 - val_accuracy: 0.9131
# Epoch 40/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4333 - accuracy: 0.8701 - val_loss: 0.3182 - val_accuracy: 0.9136
# Epoch 41/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4290 - accuracy: 0.8711 - val_loss: 0.3136 - val_accuracy: 0.9155
# Epoch 42/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.4210 - accuracy: 0.8736 - val_loss: 0.3091 - val_accuracy: 0.9164
# Epoch 43/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4191 - accuracy: 0.8732 - val_loss: 0.3051 - val_accuracy: 0.9168
# Epoch 44/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4133 - accuracy: 0.8755 - val_loss: 0.3008 - val_accuracy: 0.9174
# Epoch 45/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.4092 - accuracy: 0.8751 - val_loss: 0.2971 - val_accuracy: 0.9181
# Epoch 46/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.4033 - accuracy: 0.8778 - val_loss: 0.2930 - val_accuracy: 0.9200
# Epoch 47/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3980 - accuracy: 0.8795 - val_loss: 0.2891 - val_accuracy: 0.9210
# Epoch 48/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3946 - accuracy: 0.8807 - val_loss: 0.2858 - val_accuracy: 0.9216
# Epoch 49/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3862 - accuracy: 0.8836 - val_loss: 0.2819 - val_accuracy: 0.9220
# Epoch 50/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3859 - accuracy: 0.8820 - val_loss: 0.2787 - val_accuracy: 0.9229
# Epoch 51/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3788 - accuracy: 0.8855 - val_loss: 0.2754 - val_accuracy: 0.9232
# Epoch 52/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3744 - accuracy: 0.8864 - val_loss: 0.2723 - val_accuracy: 0.9247
# Epoch 53/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3732 - accuracy: 0.8873 - val_loss: 0.2695 - val_accuracy: 0.9247
# Epoch 54/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3660 - accuracy: 0.8909 - val_loss: 0.2659 - val_accuracy: 0.9259
# Epoch 55/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3643 - accuracy: 0.8897 - val_loss: 0.2630 - val_accuracy: 0.9264
# Epoch 56/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3596 - accuracy: 0.8907 - val_loss: 0.2606 - val_accuracy: 0.9274
# Epoch 57/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3564 - accuracy: 0.8926 - val_loss: 0.2577 - val_accuracy: 0.9280
# Epoch 58/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3533 - accuracy: 0.8930 - val_loss: 0.2550 - val_accuracy: 0.9288
# Epoch 59/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3523 - accuracy: 0.8934 - val_loss: 0.2525 - val_accuracy: 0.9295
# Epoch 60/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3492 - accuracy: 0.8940 - val_loss: 0.2502 - val_accuracy: 0.9300
# Epoch 61/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3432 - accuracy: 0.8970 - val_loss: 0.2478 - val_accuracy: 0.9300
# Epoch 62/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3417 - accuracy: 0.8972 - val_loss: 0.2452 - val_accuracy: 0.9312
# Epoch 63/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3366 - accuracy: 0.8984 - val_loss: 0.2424 - val_accuracy: 0.9313
# Epoch 64/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3327 - accuracy: 0.8996 - val_loss: 0.2401 - val_accuracy: 0.9320
# Epoch 65/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3314 - accuracy: 0.9008 - val_loss: 0.2380 - val_accuracy: 0.9324
# Epoch 66/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3307 - accuracy: 0.9008 - val_loss: 0.2356 - val_accuracy: 0.9332
# Epoch 67/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3249 - accuracy: 0.9012 - val_loss: 0.2336 - val_accuracy: 0.9336
# Epoch 68/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3243 - accuracy: 0.9018 - val_loss: 0.2315 - val_accuracy: 0.9336
# Epoch 69/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.3196 - accuracy: 0.9037 - val_loss: 0.2291 - val_accuracy: 0.9343
# Epoch 70/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3174 - accuracy: 0.9042 - val_loss: 0.2272 - val_accuracy: 0.9346
# Epoch 71/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3168 - accuracy: 0.9038 - val_loss: 0.2254 - val_accuracy: 0.9354
# Epoch 72/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3118 - accuracy: 0.9054 - val_loss: 0.2235 - val_accuracy: 0.9351
# Epoch 73/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.3102 - accuracy: 0.9060 - val_loss: 0.2216 - val_accuracy: 0.9360
# Epoch 74/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.3077 - accuracy: 0.9081 - val_loss: 0.2195 - val_accuracy: 0.9366
# Epoch 75/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3041 - accuracy: 0.9072 - val_loss: 0.2178 - val_accuracy: 0.9366
# Epoch 76/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3020 - accuracy: 0.9093 - val_loss: 0.2159 - val_accuracy: 0.9376
# Epoch 77/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.3013 - accuracy: 0.9088 - val_loss: 0.2140 - val_accuracy: 0.9382
# Epoch 78/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2986 - accuracy: 0.9106 - val_loss: 0.2125 - val_accuracy: 0.9384
# Epoch 79/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2932 - accuracy: 0.9110 - val_loss: 0.2107 - val_accuracy: 0.9385
# Epoch 80/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.2935 - accuracy: 0.9117 - val_loss: 0.2094 - val_accuracy: 0.9393
# Epoch 81/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2914 - accuracy: 0.9114 - val_loss: 0.2076 - val_accuracy: 0.9393
# Epoch 82/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2896 - accuracy: 0.9120 - val_loss: 0.2060 - val_accuracy: 0.9401
# Epoch 83/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.2876 - accuracy: 0.9133 - val_loss: 0.2044 - val_accuracy: 0.9406
# Epoch 84/100
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.2835 - accuracy: 0.9144 - val_loss: 0.2028 - val_accuracy: 0.9408
# Epoch 85/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2810 - accuracy: 0.9150 - val_loss: 0.2012 - val_accuracy: 0.9414
# Epoch 86/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2812 - accuracy: 0.9149 - val_loss: 0.2001 - val_accuracy: 0.9416
# Epoch 87/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2803 - accuracy: 0.9153 - val_loss: 0.1985 - val_accuracy: 0.9422
# Epoch 88/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2751 - accuracy: 0.9176 - val_loss: 0.1969 - val_accuracy: 0.9430
# Epoch 89/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2742 - accuracy: 0.9173 - val_loss: 0.1956 - val_accuracy: 0.9429
# Epoch 90/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.2726 - accuracy: 0.9177 - val_loss: 0.1942 - val_accuracy: 0.9431
# Epoch 91/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.2717 - accuracy: 0.9178 - val_loss: 0.1928 - val_accuracy: 0.9437
# Epoch 92/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2697 - accuracy: 0.9183 - val_loss: 0.1915 - val_accuracy: 0.9443
# Epoch 93/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2682 - accuracy: 0.9190 - val_loss: 0.1904 - val_accuracy: 0.9443
# Epoch 94/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2663 - accuracy: 0.9206 - val_loss: 0.1889 - val_accuracy: 0.9445
# Epoch 95/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2638 - accuracy: 0.9204 - val_loss: 0.1876 - val_accuracy: 0.9447
# Epoch 96/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2630 - accuracy: 0.9203 - val_loss: 0.1866 - val_accuracy: 0.9447
# Epoch 97/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.2614 - accuracy: 0.9194 - val_loss: 0.1852 - val_accuracy: 0.9459
# Epoch 98/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2598 - accuracy: 0.9219 - val_loss: 0.1839 - val_accuracy: 0.9455
# Epoch 99/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.2567 - accuracy: 0.9230 - val_loss: 0.1827 - val_accuracy: 0.9462
# Epoch 100/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2546 - accuracy: 0.9237 - val_loss: 0.1816 - val_accuracy: 0.9464
# Test loss: 0.18155383853465318
# Test accuracy: 0.946399986743927

# %%
model.save('mnist.h5')
# Out:
# /home/jake/venv/lib/python3.7/site-packages/keras/engine/saving.py:165: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
