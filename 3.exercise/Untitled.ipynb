# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import PIL
import matplotlib.pyplot as plt

# %%
import torch
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
from PIL import Image
import cv2
transform = transforms.Compose([
    #transforms.Resize(32),
    transforms.ToTensor(),
])

# %%
from torchvision.models import resnet50

# %%
train = torchvision.datasets.MNIST(root='/mnt/3CE35B99003D727B/input/pytorch/data', train=True,
                                                download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train, batch_size=1, shuffle=False)

# %%
net = resnet50(pretrained=True).cuda()
net.eval(),resnet.cuda()
# Out:
# (ResNet(
#    (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#    (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (relu): ReLU(inplace=True)
#    (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#    (layer1): Sequential(
#      (0): Bottleneck(
#        (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (relu): ReLU(inplace=True)
#        (downsample): Sequential(
# ...

# %%
def get_camdic(net, type, layer):
    cam_dict = dict()

    resnet_model_dict = dict(type=type, arch=net, layer_name=layer, input_size=(28, 28))
    resnet_gradcam = GradCAM(resnet_model_dict, True)
    resnet_gradcampp = GradCAMpp(resnet_model_dict, True)
    cam_dict[type] = [resnet_gradcam, resnet_gradcampp]
    return cam_dict

# %%
cam_dict = get_camdic(resnet,'resnet','layer3')
images = []
masks = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c57d256c57de> in <module>
# ----> 1 cam_dict = get_camdic(resnet,'resnet','layer3')
#       2 images = []
#       3 masks = []
#
# <ipython-input-24-57ec786e7b61> in get_camdic(net, type, layer)
#       3
#       4     resnet_model_dict = dict(type=type, arch=net, layer_name=layer, input_size=(28, 28))
# ----> 5     resnet_gradcam = GradCAM(resnet_model_dict, True)
#       6     resnet_gradcampp = GradCAMpp(resnet_model_dict, True)
#       7     cam_dict[type] = [resnet_gradcam, resnet_gradcampp]
#
# NameError: name 'GradCAM' is not defined

# %%
resnet_model_dict = dict(type=type, arch=net, layer_name='layer3', input_size=(28, 28))
resnet_model_dict
# Out:
# {'type': type, 'arch': ResNet(
#    (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#    (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (relu): ReLU(inplace=True)
#    (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#    (layer1): Sequential(
#      (0): Bottleneck(
#        (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#        (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (relu): ReLU(inplace=True)
# ...
